# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('14-8_cam_2_image_3.tif',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
output = cimg.copy()

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT, 1.5, 1700)


circles = np.uint16(np.around(circles))
for (x, y, r) in circles[0,:]:
    # draw the outer circle
    cv2.circle(output,(x, y), int(1.82*r),(0,255,0),3)
    # draw the center of the circle
    cv2.circle(output,(x,y),2,(0,0,255),4)
plt.imshow(output)
plt.show()

crop_img = output[y-int(1.82*r):y, x-int(1.82*r):x]

plt.imshow(crop_img)
#plt.imshow(np.hstack([output, crop_img]))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('14-8_cam_2_image_3.tif',0)
img = cv2.medianBlur(img,5)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
output = cimg.copy()

circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT, 1.5, 1700)


circles = np.uint16(np.around(circles))
for (x, y, r) in circles[0,:]:
    # draw the outer circle
    cv2.circle(output,(x, y), int(1.82*r),(0,255,0),3)
    # draw the center of the circle
    cv2.circle(output,(x,y),2,(0,0,255),4)
plt.imshow(output)
plt.show()

crop_img = output[y-r:y+r, x-r:x+r]

plt.imshow(crop_img)
#plt.imshow(np.hstack([output, crop_img]))
plt.show()
cv2.waitKey(0)
cv2.destroyAllWindows()
